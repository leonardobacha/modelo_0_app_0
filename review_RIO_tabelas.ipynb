# %%
# !pip install pandas
# !pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.5 MB 330.7 kB/s eta 0:00:34
#    - -------------------------------------- 0.5/11.5 MB 330.7 kB/s eta 0:00:34
#    - -------------------------------------- 0.5/11.5 MB 330.7 kB/s eta 0:00:34
#    -- ------------------------------------- 0.8/11.5 MB 336.9 kB/s eta 0:00:32
# ...

# %%
import pandas as pd

# %%
review = pd.read_excel('df1.xlsx',sheet_name='Sheet1')

# %%
review.describe()
# Out:
#        Unnamed: 0  Temp (◦C)  SPM (mg·L−1)    O.D. (%)  Cond (µS/cm)  \
# count  202.000000  54.000000     22.000000   85.000000     69.000000
# mean   100.500000  23.928704    387.863636   68.239412   7103.274928
# std     58.456537   6.281880    525.003700   23.930288  15019.888239
# min      0.000000   6.580000      9.000000    1.100000      3.500000
# 25%     50.250000  22.550000     16.750000   55.400000     53.600000
# 50%    100.500000  25.500000    138.500000   72.500000     91.000000
# 75%    150.750000  27.900000    647.750000   86.000000    948.000000
# max    201.000000  31.600000   1877.000000  103.300000  54000.000000
#
#           Turbidez         Sal    pH (NBS)  OD\n(mg⋅L)  TN (mg/L)  ...  \
# count   135.000000  102.000000  147.000000  143.000000  72.000000  ...
# mean    350.688852   68.539218    7.067075    5.379448   1.420238  ...
# std     953.354360  154.511925    3.143738    0.908690   2.649784  ...
# ...

# %%
#review.to_excel(r'C:\Users\USER\Desktop\df1.xlsx', index=True)
#review.to_excel('df1.xlsx', index=True)

# %%
review.describe().to_excel('resumo.xlsx', index=True)

# %%
#review.pivot_table(index=["date"], columns=["river"],values=["events"],aggfunc=['sum'])#.to_excel(r'C:\Users\USER\Desktop\het.xlsx', index=True)
review.groupby(['River']).std(numeric_only=True).reset_index().to_excel('dfdesvpad.xlsx', index=True)
review.groupby(['River']).mean(numeric_only=True).reset_index().to_excel('mean.xlsx', index=True)

# %%
review.groupby(['Location']).mean(numeric_only=True).to_excel('Location_mean_2.xlsx', index=True)

# %%
review.groupby(['Location']).count().to_excel('Count_Location.xlsx',index=True)

# %%
review.groupby(['Location']).std(numeric_only=True).to_excel('Location_STD_2.xlsx', index=True)

# %%
#!pip install matplotlib numpy scipy scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ------------------- -------------------- 3.9/8.1 MB 19.4 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 23.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/41.0 MB ? eta -:--:--
#    ----------- ---------------------------- 11.3/41.0 MB 54.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 22.5/41.0 MB 54.0 MB/s eta 0:00:01
#    ---------------------------------------  40.6/41.0 MB 65.7 MB/s eta 0:00:01
#    ---------------------------------------- 41.0/41.0 MB 59.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/10.7 MB ? eta -:--:--
#    ---------------------------------------- 10.7/10.7 MB 77.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
# ...

# %% [markdown]
# AQUI COMEÇA O ESTUDO DE FATO - MODELOS

# %%
import pandas as pd
review = pd.read_excel('Location_mean.xlsx',sheet_name='TABELA')

# %%
# import pandas as pd
# review = pd.read_excel('df1.xlsx',sheet_name='Sheet1')
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
#from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
from sklearn.pipeline import Pipeline, make_pipeline
#from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, accuracy_score
from sklearn.impute import SimpleImputer

array = review.values
X = array[:, 8:].astype(float)
y = array[:, 6]

test_size = 0.30
seed = 7
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=seed)

pipeline = Pipeline([
    ('preprocessing', StandardScaler()),
    ('imputer', SimpleImputer(strategy='mean')),  # Você pode escolher 'median', 'most_frequent' etc.
    ('model', RandomForestClassifier(random_state=42))
])

param_grid = [
    {'model__n_estimators': [100, 200, 1000]},
    {'model__max_features': [6, 8, 10]},
    {'model__max_depth': [None, 10, 20]},
]
grid_search = GridSearchCV(pipeline, param_grid, cv=3,
                           scoring='accuracy')
grid_search.fit(X, y)
# Out:
# C:\Users\leoba\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# C:\Users\leoba\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# C:\Users\leoba\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
# ...

# %%
grid_search.best_params_
grid_search.best_estimator_
cv_res = pd.DataFrame(grid_search.cv_results_)
cv_res.sort_values(by="mean_test_score", ascending=False, inplace=True)
cv_res.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.069774      0.009402         0.002337        0.000119
# 1       0.125267      0.000879         0.003889        0.000129
# 2       0.604177      0.011299         0.015528        0.000372
# 3       0.059218      0.001032         0.002208        0.000052
# 4       0.060061      0.002204         0.002350        0.000263
#
#    param_model__n_estimators  param_model__max_features  \
# 0                      100.0                        NaN
# 1                      200.0                        NaN
# 2                     1000.0                        NaN
# 3                        NaN                        6.0
# 4                        NaN                        8.0
#
#   param_model__max_depth                         params  split0_test_score  \
# 0                    NaN   {'model__n_estimators': 100}                1.0
# 1                    NaN   {'model__n_estimators': 200}                1.0
# ...

# %%
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingRandomSearchCV
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint

param_distribs = {'model__n_estimators': randint(low=100, high=1000),
                  'model__max_features': randint(low=2, high=20)}

rnd_search = RandomizedSearchCV(
    pipeline, param_distributions=param_distribs, n_iter=10, cv=3,
    scoring='accuracy', random_state=42)

rnd_search.fit(X, y)
# Out:
# C:\Users\leoba\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# C:\Users\leoba\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# C:\Users\leoba\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
# ...

# %%
final_model = rnd_search.best_estimator_  # includes preprocessing
feature_importances = final_model["model"].feature_importances_
feature_importances.round(2)
# Out:
# array([0.03, 0.  , 0.01, 0.08, 0.11, 0.05, 0.08, 0.03, 0.02, 0.04, 0.01,
#        0.  , 0.05, 0.  , 0.  , 0.  , 0.  , 0.04, 0.04, 0.  , 0.02, 0.01,
#        0.01, 0.02, 0.  , 0.  , 0.  , 0.02, 0.  , 0.  , 0.01, 0.  , 0.04,
#        0.  , 0.01, 0.  , 0.  , 0.01, 0.01, 0.  , 0.01, 0.01, 0.  , 0.04,
#        0.07, 0.03, 0.02, 0.01, 0.01, 0.  , 0.  , 0.  , 0.  , 0.02])

# %%
final_predictions = final_model.predict(X_test)

# final_rmse = final_model.score(y_test, final_predictions)
# print(final_rmse)

import joblib

joblib.dump(final_model, "my_california_housing_model.pkl")
# Out:
# ['my_california_housing_model.pkl']

# %%
import joblib

# extra code – excluded for conciseness
from sklearn.cluster import KMeans
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.metrics.pairwise import rbf_kernel

# def column_ratio(X):
#     return X[:, [0]] / X[:, [1]]

#class ClusterSimilarity(BaseEstimator, TransformerMixin):
#    [...]

final_model_reloaded = joblib.load("my_california_housing_model.pkl")

array = review.values
X = array[:, 8:].astype(float)
y = array[:, 6]

new_data = X[:15]  # pretend these are new districts
predictions = final_model_reloaded.predict(new_data)

# %%
predictions
# Out:
# array(['Nutrientes', 'Nutrientes', 'Nutrientes', 'Nutrientes',
#        'Nutrientes', 'Esgoto', 'Esgoto', 'Esgoto', 'Esgoto', 'Esgoto',
#        'Esgoto', 'Esgoto', 'Esgoto', 'Agricultura', 'Agricultura'],
#       dtype=object)

# %% [markdown]
# CAPÍTULO 3: CLASSIFICAÇÃO

# %%
from sklearn.model_selection import cross_val_score

cross_val_score(final_model, X_train, y_train, cv=3, scoring="accuracy")
# Out:
# C:\Users\leoba\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\model_selection\_split.py:811: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   warnings.warn(
# C:\Users\leoba\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# C:\Users\leoba\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# ...

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix


y_train_pred = cross_val_predict(final_model, X_train, y_train, cv=3)

cm = confusion_matrix(y_train, y_train_pred)
cm
# Out:
# C:\Users\leoba\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\model_selection\_split.py:811: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   warnings.warn(
# C:\Users\leoba\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# C:\Users\leoba\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# ...

# %%
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import f1_score

precision = precision_score(y_train, y_train_pred, average='macro')  # == 3530 / (687 + 3530)

recall = recall_score(y_train, y_train_pred, average='macro')

f1 = f1_score(y_train, y_train_pred, average='macro')

print(f'Precision: {precision:.3f}')
print(f'Recall: {recall:.3f}')
print(f'F1-score: {f1:.3f}')
# Out:
# Precision: 0.765
# Recall: 0.750
# F1-score: 0.753
# C:\Users\leoba\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\metrics\_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import precision_recall_curve
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import numpy as np

# Primeiro, obter as probabilidades com cross_val_predict
y_probas = cross_val_predict(
    final_model, X_train, y_train, cv=3, method="predict_proba"
)

# Agora, vamos descobrir os nomes das classes (caso estejam em string)
le = LabelEncoder()
le.fit(y_train)

# Loop para fazer uma Precision-Recall Curve para cada classe
for classe_alvo in le.classes_:
    print(f"\nClasse: {classe_alvo}")

    # Converter y_train em binário (1 para a classe alvo, 0 para as demais)
    y_true_binary = (y_train == classe_alvo).astype(int)

    # Descobrir o índice da classe na saída do predict_proba
    classe_index = list(le.classes_).index(classe_alvo)

    # Pegar as probabilidades da classe alvo
    y_scores = y_probas[:, classe_index]

    # Calcular a curva Precision-Recall
    precisions, recalls, thresholds = precision_recall_curve(y_true_binary, y_scores)

    # Plotar o gráfico
    plt.figure(figsize=(8, 4))
    plt.plot(thresholds, precisions[:-1], "b--", label="Precision", linewidth=2)
    plt.plot(thresholds, recalls[:-1], "g-", label="Recall", linewidth=2)
    plt.xlabel("Threshold")
    plt.ylabel("Score")
    plt.title(f"Precision-Recall Curve - Classe: {classe_alvo}")
    plt.legend(loc="best")
    plt.grid(True)
    plt.show()
# Out:
# C:\Users\leoba\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\model_selection\_split.py:811: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   warnings.warn(
# C:\Users\leoba\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# C:\Users\leoba\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# ...

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# Primeiro transforme as classes em números, caso ainda não tenha feito
le = LabelEncoder()
y_train_encoded = le.fit_transform(y_train)

# Identifique o índice da classe alvo dentro do predict_proba
classe_alvo_nome = "Esgoto"  # Nome exato da sua classe alvo
classe_alvo_indice = list(le.classes_).index(classe_alvo_nome)

# Transformar y_train para binário (One-vs-Rest)
y_true_binary = (y_train == classe_alvo_nome).astype(int)

# Pegar a coluna de probabilidades da classe alvo
y_scores_forest = y_probas_forest[:, classe_alvo_indice]

# Agora sim, calcular a curva Precision-Recall
precisions_forest, recalls_forest, thresholds_forest = precision_recall_curve(
    y_true_binary, y_scores_forest
)

# Plotar
plt.figure(figsize=(6, 5))
plt.plot(recalls_forest, precisions_forest, "b-", linewidth=2, label="Random Forest")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title(f"Precision-Recall Curve - Classe: {classe_alvo_nome}")
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import ConfusionMatrixDisplay

y_train_pred = cross_val_predict(final_model, X_train, y_train, cv=3)
plt.rc('font', size=9)  # extra code – make the text smaller
ConfusionMatrixDisplay.from_predictions(y_train, y_train_pred)
plt.show()
# Out:
# C:\Users\leoba\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\model_selection\_split.py:811: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   warnings.warn(
# C:\Users\leoba\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# C:\Users\leoba\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# ...
